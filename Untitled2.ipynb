# %% [markdown]
# <a href="https://colab.research.google.com/github/ronhasgreyrat/summer-internship/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from textblob import TextBlob
import plotly.graph_objects as go
import plotly.express as xp

# %%
modi=pd.read_csv('/content/modi_reviews.csv')
rahul=pd.read_csv('/content/rahul_reviews.csv')

# %%
modi.head()
# Out:
#    Unnamed: 0             User  \
# 0           0  advosushildixit
# 1           1           jiaeur
# 2           2    PVenkatGandhi
# 3           3      TheNirbhay1
# 4           4      ShakeChilli
#
#                                                Tweet
# 0  @anjanaomkashyap I am seeing you as future #bj...
# 1  #LokSabhaElections2019 \n23rd May 2019 will re...
# 2  #LokSabhaElections2019 \n23rd May 2019 will re...
# 3  PM Modi creates a new record of being the only...
# 4  @abhijitmajumder Appointment of Successor! \n\...

# %%
modi.shape
# Out:
# (25688, 3)

# %%
TextBlob(modi["Tweet"][10]).sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
TextBlob(rahul["Tweet"][2]).sentiment
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)

# %%
modi['Tweet']=modi['Tweet'].astype(str)
rahul['Tweet']=rahul['Tweet'].astype(str)

def find_polarity(review):
 return tb(review).sentiment.polarity

# %%
modi['Tweet']=modi['Tweet'].apply(find_polarity)
rahul['Tweet']=rahul['Tweet'].apply(find_polarity)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1544/2394315387.py in <cell line: 0>()
# ----> 1 modi['Tweet']=modi['Tweet'].apply(find_polarity)
#       2 rahul['Tweet']=rahul['Tweet'].apply(find_polarity)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4922             args=args,
#    4923             kwargs=kwargs,
# -> 4924         ).apply()
#    4925
#    4926     def _reindex_indexer(
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply(self)
#    1425
#    1426         # self.func is Callable
# -> 1427         return self.apply_standard()
#    1428
#    1429     def agg(self):
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1505         #  Categorical (GH51645).
# ...
